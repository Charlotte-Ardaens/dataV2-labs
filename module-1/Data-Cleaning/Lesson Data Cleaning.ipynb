# %%
import pandas as pd

# %%
import os

# %%
os.chdir('C:\\Users\\admin\\Documents\\Ironhack_lessons\\Module 1\\vehicles')

# %%
df=pd.read_csv('vehicles_messy.csv')
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
# Find how many rows and columns the dataframe contains
df.shape
# Out:
# (37843, 83)

# %%
# Retrieve some info about each columns (number of non null values and datatype)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37843 entries, 0 to 37842
# Data columns (total 83 columns):
# barrels08          37843 non-null float64
# barrelsA08         37843 non-null float64
# charge120          37843 non-null float64
# charge240          37843 non-null float64
# city08             37843 non-null int64
# city08U            37843 non-null float64
# cityA08            37843 non-null int64
# cityA08U           37843 non-null float64
# cityCD             37843 non-null float64
# cityE              37843 non-null float64
# cityUF             37843 non-null float64
# co2                37843 non-null int64
# co2A               37843 non-null int64
# co2TailpipeAGpm    37843 non-null float64
# co2TailpipeGpm     37843 non-null float64
# comb08             37843 non-null int64
# comb08U            37843 non-null float64
# combA08            37843 non-null int64
# combA08U           37843 non-null float64
# combE              37843 non-null float64
# ...

# %% [markdown]
# #  Missing values

# %%
# Display the dataframe, retrun a boolean : True if NaN, False if not NaN
df.isna()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0          False       False      False      False   False    False    False
# 1          False       False      False      False   False    False    False
# 2          False       False      False      False   False    False    False
# 3          False       False      False      False   False    False    False
# 4          False       False      False      False   False    False    False
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838      False       False      False      False   False    False    False
# 37839      False       False      False      False   False    False    False
# 37840      False       False      False      False   False    False    False
# 37841      False       False      False      False   False    False    False
# 37842      False       False      False      False   False    False    False
#
# ...

# %%
# Find the number of True (ie NaN) per column
df.isna().sum()
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31705
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
# Same as previous but select just the columns that have at least one NaN
df_na=df.isna().sum()
df_na[df_na>0]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
# Find the percentage of NaN values
(df_na[df_na>0]/df.shape[0]*100).round(2)
# Out:
# cylinders      0.33
# displ          0.32
# drive          3.14
# eng_dscr      40.70
# trany          0.03
# guzzler       93.97
# trans_dscr    60.24
# tCharger      86.30
# sCharger      98.24
# atvType       91.88
# fuelType2     96.28
# rangeA        96.29
# evMotor       98.51
# mfrCode       81.44
# c240Dscr      99.90
# c240bDscr     99.90
# startStop     83.78
# dtype: float64

# %%
#find the numer of True (ie NAn) per column 
df_na=df.isna().sum()

# %%
df_missing=(df_na[df_na>0]/df.shape[0]*100).round(2)

# %%
#create a list with the name of the columns we want to drop - more than 75% of the valuuesthat are NaN
drop_cols=df_missing[df_missing>75].index

# %%
#delete the columns from the initial dataframe
df2=df.drop(drop_cols,axis=1)

# %%
#we are ok with the changes and we re-save new df in df
df.drop(drop_cols, axis=1, inplace=True)
