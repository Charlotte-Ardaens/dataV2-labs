# %%
import pandas as pd

# %%
import os

# %%
os.chdir('C:\\Users\\admin\\Documents\\Ironhack_lessons\\Module 1\\vehicles')

# %%
#pour voir dans quelle directory on est 
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents\\Ironhack_lessons\\Module 1\\vehicles'

# %%
#pour voir les fichiers dans la directory
os.listdir()
# Out:
# ['.DS_Store',
#  'vehicles.csv',
#  'vehicles.json',
#  'vehicles.xlsx',
#  'vehicles_messy.csv',
#  'vehicles_pipe.txt',
#  'vehicles_tab.txt']

# %%
df_csv=pd.read_csv('vehicles.csv')

# %%
df_csv.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df_tab=pd.read_csv('vehicles_tab.txt', sep='\t')

# %%
df_tab.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df_pipe=pd.read_csv('vehicles_pipe.txt', sep='|')
df_pipe.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
#exporter en csv
df_tab.to_csv('vehicles_transformed.txt', sep=',',index=False)
os.listdir()
# Out:
# ['.DS_Store',
#  'vehicles.csv',
#  'vehicles.json',
#  'vehicles.xlsx',
#  'vehicles_messy.csv',
#  'vehicles_pipe.txt',
#  'vehicles_tab.txt',
#  'vehicles_transformed.txt']

# %%
#prend BEAUCOUP de temps
df=pd.read_excel('vehicles.xlsx')

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
#should have 'orient' but it was correctly oriented so work like this
df=pd.read_json('vehicles.json')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
#exporter en jason ici, on perd le nom de colonnes a cause de values
df.to_json('new_json.json',orient='values')

# %%
#download pymysql
# !pip install pymysql

# %%
import pymysql

# %%
from sqlalchemy import create_engine

# %%
username='root'
host='localhost'
password='Poule!!e1'
database_name='publications'

# %%
engine=create_engine(f"""mysql+pymysql://{username}:{password}@{host}/{database_name}""")

# %%
pd.read_sql_query('SELECT * FROM sales', engine)
# Out:
#    stor_id   ord_num   ord_date  qty    payterms title_id
# 0     6380      6871 1994-09-14    5      Net 60   BU1032
# 1     6380      722a 1994-09-13    3      Net 60   PS2091
# 2     7066     A2976 1993-05-24   50      Net 30   PC8888
# 3     7066  QA7442.3 1994-09-13   75  ON invoice   PS2091
# 4     7067     D4482 1994-09-14   10      Net 60   PS2091
# 5     7067     P2121 1992-06-15   40      Net 30   TC3218
# 6     7067     P2121 1992-06-15   20      Net 30   TC4203
# 7     7067     P2121 1992-06-15   20      Net 30   TC7777
# 8     7131   N914008 1994-09-14   20      Net 30   PS2091
# 9     7131   N914014 1994-09-14   25      Net 30   MC3021
# 10    7131    P3087a 1993-05-29   20      Net 60   PS1372
# 11    7131    P3087a 1993-05-29   25      Net 60   PS2106
# 12    7131    P3087a 1993-05-29   15      Net 60   PS3333
# 13    7131    P3087a 1993-05-29   25      Net 60   PS7777
# 14    7896    QQ2299 1993-10-28   15      Net 60   BU7832
# ...
